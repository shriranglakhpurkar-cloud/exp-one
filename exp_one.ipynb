# %% [markdown]
# shrirang lakhpurkar EXP1:introduction to python

# %%
x,y,z="orange","apple","banana"
print(x)
# Out:
# orange

# %%
x=2
y=2.5
z="shrirang"
w=True
print(type(x))
print(type(y))
print(type(z))
print(type(w))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x=10
y=5
add=x+y
sub=x-y
mul=x*y
div=x/y
exp=x**y
print(add)
print(sub)
print(mul)
print(div)
print(exp)
# Out:
# 15
# 5
# 50
# 2.0
# 100000

# %%
x=int(input("enter value of x="))
y=int(input("enter value of y="))
add=x+y
sub=x-y
mul=x*y
div=x/y
exp=x**y
print(add)
print(sub)
print(mul)
print(div)
print(exp)
# Out:
# enter value of x=12
# enter value of y=14
# 26
# -2
# 168
# 0.8571428571428571
# 1283918464548864

# %%
x=int(input("enter value of x="))
import math
area=(math.pi)*x*x
print(area)
# Out:
# enter value of x=5
# 78.53981633974483

# %%
import math
print(math.log(2.5))
# Out:
# 0.9162907318741551

# %%
a = float(input("Enter the first number (a): "))
b = float(input("Enter the second number (b): "))

if a > b:
    print(f"{a} is greater than {b}")
elif a < b:
    print(f"{a} is smaller than {b}")
else:
    print(f"{a} is equal to {b}")
# Out:
# Enter the first number (a): 10
# Enter the second number (b): 25
# 10.0 is smaller than 25.0
